# %%
mas = 'hi every one my name is '
def greet_user():
    print(mas.upper()+'ASIF')
greet_user()
def greet_user(username):
    print(mas.upper()+username.upper())
greet_user('atif')
greet_user('ali')
def greet_user(username,lastname):
    print(mas.upper()+username.upper()+lastname.upper())
greet_user('atif ','qureshi')
greet_user('ali ','kk')
def greet_user(username,lastname):
    print(mas.upper()+username.upper()+lastname.upper())
greet_user(lastname='yousf zaee ',username='saba ')
def greet_user(username,lastname,laction='hyderabad'):
    print(mas.upper()+username.upper()+lastname.upper()+'FROM '+laction.upper())
greet_user('Babar ','qureshi ')
greet_user('owais ','arae ')
def greet_user(username,lastname,laction='karachi'):
    print(mas.upper()+username.upper()+lastname.upper()+'FROM '+laction.upper())
greet_user(lastname='Qulander bashe ',username='syed ')
def greet_user(username,lastname,phone='03243073580'):
    fullname= mas+username.upper()+lastname.upper()+' MY PHONE NUMBER IS '+phone
    return fullname.upper()
a=greet_user('hader ali ',lastname='shah')
print(a)
def greet_user(*username):
    for i in username:
        print(mas.upper()+str(i).upper())
greet_user('ali','atif','saba')
def greet_user(*usernames,**info):
    z=0
    for i in info:
        print (str(usernames[z])+str(info))
        z+=1
greet_user('atif','ali','saba',a=['g','y','u'],b=[7,9,8],c=['l','o','j'])
def greet_user(*usernames,**info):
    for i in usernames:
        print (i,info)
greet_user('atif','ali ','saba','aiya',doctor = ['hyderabad','karachi','sakkar'])
def greet_user(firstname,lastname,mn='',phone=''):
    if mn:
        fullname = firstname+' '+mn +' '+lastname
    elif phone:
        fullname = firstname+' '+lastname+' '+phone
    else:
        fullname= firstname+' '+mn+' '+lastname+' '+phone
    return fullname.title()
b=greet_user('mohammad','quteshi','atif')
print(b)
c=greet_user('mohammad','quteshi',phone='0324307350')
print(c)
d=greet_user('mohammad','quteshi','atif','0324307350')
print(d)
def functions():
        def greet_user(username,lastname,phone='03243073580'):
            fullname= mas+username.upper()+lastname.upper()+' MY PHONE NUMBER IS '+phone
            return fullname.upper()
        a=greet_user('hader ali ',lastname='shah')
        print(a)
        def greet_user(*username):
            for i in username:
                print(mas.upper()+str(i).upper())
        greet_user('ali','atif','saba')
functions()
def greet_user(firstname,lastname,mn='',phone=''):
    if mn:
        fullname = firstname+' '+mn +' '+lastname
    elif phone:
        fullname = firstname+' '+lastname+' '+phone
    else:
        fullname= firstname+' '+mn+' '+lastname+' '+phone
    return fullname.title()
b=greet_user('mohammad','quteshi','atif')
print(b)
c=greet_user('mohammad','quteshi',phone='0324307350')
print(c)
d=greet_user('mohammad','quteshi','atif','0324307350')
print(d)
def model(uncomplete_model,complete_model):
    while uncomplete_model:
        a = uncomplete_model.pop()
        complete_model.append(a)
uncomplete_model=['Q-mobile','sumson','pop']
complete_model=[]
model(uncomplete_model,complete_model)
def show_complete_model(complete_model):
    print('these are complete models:\n')
    for i in complete_model:
        print('\t'+i)
show_complete_model(complete_model)
# Out:
# HI EVERY ONE MY NAME IS ASIF
# HI EVERY ONE MY NAME IS ATIF
# HI EVERY ONE MY NAME IS ALI
# HI EVERY ONE MY NAME IS ATIF QURESHI
# HI EVERY ONE MY NAME IS ALI KK
# HI EVERY ONE MY NAME IS SABA YOUSF ZAEE
# HI EVERY ONE MY NAME IS BABAR QURESHI FROM HYDERABAD
# HI EVERY ONE MY NAME IS OWAIS ARAE FROM HYDERABAD
# HI EVERY ONE MY NAME IS SYED QULANDER BASHE FROM KARACHI
# HI EVERY ONE MY NAME IS HADER ALI SHAH MY PHONE NUMBER IS 03243073580
# HI EVERY ONE MY NAME IS ALI
# HI EVERY ONE MY NAME IS ATIF
# HI EVERY ONE MY NAME IS SABA
# atif{'a': ['g', 'y', 'u'], 'b': [7, 9, 8], 'c': ['l', 'o', 'j']}
# ali{'a': ['g', 'y', 'u'], 'b': [7, 9, 8], 'c': ['l', 'o', 'j']}
# saba{'a': ['g', 'y', 'u'], 'b': [7, 9, 8], 'c': ['l', 'o', 'j']}
# atif {'doctor': ['hyderabad', 'karachi', 'sakkar']}
# ali  {'doctor': ['hyderabad', 'karachi', 'sakkar']}
# saba {'doctor': ['hyderabad', 'karachi', 'sakkar']}
# aiya {'doctor': ['hyderabad', 'karachi', 'sakkar']}
# Mohammad Atif Quteshi
# ...

# %%
class Car():
    def __init__(self,car_name,car_number):
        self.car_name=car_name
        self.car_number=car_number
        self.number_of_gar = 2
        self.list_gar = []
    def gc_info(self):
        info = 'the car name is '+self.car_name+"it's  nnumber is "+self.car_number
        return info.upper()
    def gar(self):
        print('the number of gars are ',self.number_of_gar)
    def upgard_gar(self,update):
        self.list_gar.append(update)
        if update > self.number_of_gar:
            print('you can go higher ')
            if update==9:
                print('current gar Level is '+str(update))
a=Car("maharan, ",'78yh')
print(a.gc_info())
print('\nthis is by modification')
a.number_of_gar=4
a.gar()
print('\nthis is by method')
a.upgard_gar(7)
print('\nlist')
a.list_gar
a.upgard_gar(9)
# Out:
# THE CAR NAME IS MAHARAN, IT'S  NNUMBER IS 78YH
#
# this is by modification
# the number of gars are  4
#
# this is by method
# you can go higher
#
# list
# you can go higher
# current gar Level is 9

# %%
a = functions()
# Out:
# HI EVERY ONE MY NAME IS HADER ALI SHAH MY PHONE NUMBER IS 03243073580
# HI EVERY ONE MY NAME IS ALI
# HI EVERY ONE MY NAME IS ATIF
# HI EVERY ONE MY NAME IS SABA
